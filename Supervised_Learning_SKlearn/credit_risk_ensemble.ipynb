# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from matplotlib import pyplot as plt

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
X = df.drop(columns='loan_status')

# Create our target
y = df['loan_status']

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# count   68817.000000  ...        68817.000000        68817.000000
# mean    17604.142828  ...            0.052138            2.219423
# std     21835.880400  ...            0.390633            1.897432
# min         0.000000  ...            0.000000            0.000000
# 25%      6293.000000  ...            0.000000            1.000000
# 50%     12068.000000  ...            0.000000            2.000000
# 75%     21735.000000  ...            0.000000            3.000000
# max    587191.000000  ...           18.000000           19.000000
#
#        pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# count    68817.000000      68817.000000          68817.000000    68817.0
# mean        95.057627         30.626217              0.125972        0.0
# std          8.326426         33.631463              0.336732        0.0
# min         20.000000          0.000000              0.000000        0.0
# 25%         93.000000          0.000000              0.000000        0.0
# 50%        100.000000         20.000000              0.000000        0.0
# 75%        100.000000         50.000000              0.000000        0.0
# max        100.000000        100.000000              4.000000        0.0
#
#        tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# count     6.881700e+04       6.881700e+04    68817.000000
# mean      2.100332e+05       6.133843e+04    29734.128558
# std       1.928088e+05       5.738798e+04    26795.394232
# min       3.600000e+03       2.350000e+02      100.000000
# 25%       6.697700e+04       2.650300e+04    11600.000000
# 50%       1.467100e+05       4.535700e+04    22100.000000
# 75%       3.036400e+05       7.657000e+04    39300.000000
# max       3.292782e+06       1.295455e+06   509400.000000
#
#        total_il_high_credit_limit
# count                6.881700e+04
# mean                 5.572240e+04
# std                  5.095845e+04
# min                  1.270000e+02
# 25%                  2.288000e+04
# 50%                  4.200000e+04
# 75%                  7.249900e+04
# max                  1.426964e+06
#
# [8 rows x 76 columns]

# %%
# Check the balance of our target values
 
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
X
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0        10500.0    0.1719       375.35           RENT     66000.0
# 1        25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2        20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3        10000.0    0.1640       353.55           RENT     92000.0
# 4        22000.0    0.1474       520.39       MORTGAGE     52000.0
# ...          ...       ...          ...            ...         ...
# 68812    10000.0    0.1502       346.76           RENT     26000.0
# 68813    12000.0    0.2727       368.37           RENT     63000.0
# 68814     5000.0    0.1992       185.62       MORTGAGE     52000.0
# 68815    40000.0    0.0646      1225.24       MORTGAGE    520000.0
# 68816    16000.0    0.1131       350.36       MORTGAGE     72000.0
#
#       verification_status   issue_d pymnt_plan    dti  delinq_2yrs  ...  \
# 0         Source Verified  Mar-2019          n  27.24          0.0  ...
# 1                Verified  Mar-2019          n  20.23          0.0  ...
# 2                Verified  Mar-2019          n  24.26          0.0  ...
# 3                Verified  Mar-2019          n  31.44          0.0  ...
# 4            Not Verified  Mar-2019          n  18.76          0.0  ...
# ...                   ...       ...        ...    ...          ...  ...
# 68812     Source Verified  Jan-2019          n   9.60          0.0  ...
# 68813        Not Verified  Jan-2019          n  29.07          0.0  ...
# 68814     Source Verified  Jan-2019          n  14.86          0.0  ...
# 68815            Verified  Jan-2019          n   9.96          0.0  ...
# 68816            Verified  Jan-2019          n   7.02          2.0  ...
#
#        pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0                85.7             100.0                   0.0        0.0
# 1                91.2              50.0                   1.0        0.0
# 2                66.7              50.0                   0.0        0.0
# 3               100.0              50.0                   1.0        0.0
# 4               100.0               0.0                   0.0        0.0
# ...               ...               ...                   ...        ...
# 68812            80.0               0.0                   0.0        0.0
# 68813            96.2               0.0                   0.0        0.0
# 68814           100.0               0.0                   1.0        0.0
# 68815            98.2              12.5                   0.0        0.0
# 68816            94.3               0.0                   1.0        0.0
#
#        tot_hi_cred_lim total_bal_ex_mort  total_bc_limit  \
# 0              65687.0           38199.0          2000.0
# 1             271427.0           60641.0         41200.0
# 2              60644.0           45684.0          7500.0
# 3              99506.0           68784.0         19700.0
# 4             219750.0           25919.0         27600.0
# ...                ...               ...             ...
# 68812          20625.0            6798.0         11300.0
# 68813          87939.0           60350.0         13500.0
# 68814          30592.0           18611.0          3600.0
# 68815        1033574.0           95958.0        100800.0
# 68816         251486.0           74835.0         23000.0
#
#        total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                         61987.0              N                     N
# 1                         49197.0              N                     N
# 2                         43144.0              N                     N
# 3                         76506.0              N                     N
# 4                         20000.0              N                     N
# ...                           ...            ...                   ...
# 68812                      5425.0              N                     N
# 68813                     62939.0              N                     N
# 68814                     18492.0              N                     N
# 68815                     78634.0              N                     N
# 68816                     63090.0              N                     N
#
# [68817 rows x 85 columns]

# %%
X_encoded = pd.get_dummies(X)
X_encoded.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1    25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2    20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3    10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4    22000.0    0.1474       520.39     52000.0  18.76          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  issue_d_Mar-2019  \
# 0             0.0       8.0      0.0     1609.0  ...                 1
# 1             0.0      17.0      1.0    18368.0  ...                 1
# 2             0.0       8.0      0.0    13247.0  ...                 1
# 3             1.0      10.0      1.0    17996.0  ...                 1
# 4             1.0      14.0      0.0     9091.0  ...                 1
#
#    pymnt_plan_n  initial_list_status_f  initial_list_status_w  \
# 0             1                      0                      1
# 1             1                      0                      1
# 2             1                      0                      1
# 3             1                      0                      1
# 4             1                      0                      1
#
#    next_pymnt_d_Apr-2019  next_pymnt_d_May-2019  application_type_Individual  \
# 0                      0                      1                            1
# 1                      0                      1                            1
# 2                      0                      1                            1
# 3                      0                      1                            1
# 4                      0                      1                            1
#
#    application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# 0                           0                1                       1
# 1                           0                1                       1
# 2                           0                1                       1
# 3                           0                1                       1
# 4                           0                1                       1
#
# [5 rows x 95 columns]

# %%
# Split the X and y into X_train, X_test, y_train, y_test
 
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X_encoded,y, random_state=1, stratify=y)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
 
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the training and testing data
 
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
 
from imblearn.ensemble import BalancedRandomForestClassifier
rf_model = BalancedRandomForestClassifier(n_estimators=300, random_state=1)
rf_model.fit(X_train_scaled, y_train)
# Out:
# BalancedRandomForestClassifier(n_estimators=300, random_state=1)

# %%
# Display the confusion matrix
 
from sklearn.metrics import confusion_matrix
y_pred = rf_model.predict(X_test_scaled)
confusion_matrix(y_test, y_pred)
# Out:
# array([[   59,    28],
#        [ 1311, 15807]])

# %%
# Calculated the balanced accuracy score
 
from sklearn.metrics import balanced_accuracy_score 
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.80078743488403

# %%
# Print the imbalanced classification report
 
from imblearn.metrics import classification_report_imbalanced 
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.04      0.68      0.92      0.08      0.79      0.61        87
#    low_risk       1.00      0.92      0.68      0.96      0.79      0.64     17118
#
# avg / total       0.99      0.92      0.68      0.95      0.79      0.64     17205

# %%
# List the features sorted in descending order by feature importance
 
importances = rf_model.feature_importances_

sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(0.06871822411045844, 'initial_list_status'),
#  (0.06461076202267399, 'out_prncp'),
#  (0.06196733577519134, 'total_acc'),
#  (0.05927893158682057, 'revol_bal'),
#  (0.05177498150967079, 'total_rec_prncp'),
#  (0.02671933888517889, 'int_rate'),
#  (0.01872128044609144, 'debt_settlement_flag'),
#  (0.01746348042382014, 'open_acc'),
#  (0.017131584908360472, 'annual_inc'),
#  (0.016647792808655987, 'delinq_2yrs'),
#  (0.01644420667429185, 'pub_rec'),
#  (0.016247358969809535, 'open_il_12m'),
#  (0.016242973915338063, 'installment'),
#  (0.015811172597791235, 'home_ownership'),
#  (0.0157954834780441, 'total_rev_hi_lim'),
#  (0.01548683671097297, 'delinq_amnt'),
#  (0.014905579602261243, 'inq_last_12m'),
#  (0.014641432465815955, 'tot_cur_bal'),
#  (0.014543503110995453, 'max_bal_bc'),
#  (0.014120094172143582, 'num_tl_op_past_12m'),
#  (0.014017734416565408, 'acc_open_past_24mths'),
#  (0.013984639957500792, 'all_util'),
#  (0.013835259288823162, 'last_pymnt_amnt'),
#  (0.013316736535598825, 'pct_tl_nvr_dlq'),
#  (0.013065921190424467, 'tot_coll_amt'),
#  (0.012670082583113602, 'open_il_24m'),
#  (0.012562319711740927, 'num_tl_90g_dpd_24m'),
#  (0.012142373462321462, 'num_tl_30dpd'),
#  (0.011606036488238132, 'mths_since_rcnt_il'),
#  (0.01151449195277856, 'acc_now_delinq'),
#  (0.011492791756480563, 'inq_last_6mths'),
#  (0.011363301255031705, 'chargeoff_within_12_mths'),
#  (0.010851501697669045, 'num_accts_ever_120_pd'),
#  (0.010616083284810392, 'avg_cur_bal'),
#  (0.010436706736545029, 'loan_amnt'),
#  (0.010078063148314463, 'mths_since_recent_bc'),
#  (0.009272254453545434, 'pymnt_plan'),
#  (0.00919551922268713, 'num_actv_rev_tl'),
#  (0.008966760687901493, 'num_actv_bc_tl'),
#  (0.008897922486335785, 'num_rev_accts'),
#  (0.008876574333295417, 'bc_open_to_buy'),
#  (0.00878912687099566, 'mort_acc'),
#  (0.00868823632318983, 'open_rv_12m'),
#  (0.008519711659788248, 'mths_since_recent_inq'),
#  (0.008231921580950785, 'mo_sin_rcnt_rev_tl_op'),
#  (0.00807232585873371, 'mo_sin_old_rev_tl_op'),
#  (0.007843577543817943, 'il_util'),
#  (0.007833894065777952, 'total_bal_il'),
#  (0.007519199584581832, 'open_rv_24m'),
#  (0.0074221953326226945, 'num_rev_tl_bal_gt_0'),
#  (0.007403259296961156, 'open_act_il'),
#  (0.00724688824045749, 'mo_sin_rcnt_tl'),
#  (0.006692394809330262, 'num_op_rev_tl'),
#  (0.00659424828372584, 'issue_d'),
#  (0.006508671299599458, 'out_prncp_inv'),
#  (0.006269627984558683, 'collections_12_mths_ex_med'),
#  (0.0061884808483942694, 'bc_util'),
#  (0.006165532815831571, 'application_type'),
#  (0.00567685418215394, 'next_pymnt_d'),
#  (0.005276211621467413, 'policy_code'),
#  (0.0052062591849195905, 'open_acc_6m'),
#  (0.004405741699891588, 'verification_status'),
#  (0.004223310335495193, 'hardship_flag'),
#  (0.003254422416819945, 'mo_sin_old_il_acct'),
#  (0.0032523589758694516, 'collection_recovery_fee'),
#  (0.0027077456237629095, 'total_il_high_credit_limit'),
#  (0.002220598818819841, 'tax_liens'),
#  (0.002095752660142316, 'tot_hi_cred_lim'),
#  (0.0020845887383846716, 'pub_rec_bankruptcies'),
#  (0.0018482640896756216, 'total_bal_ex_mort'),
#  (0.0016490162278594849, 'num_sats'),
#  (0.001438804751351013, 'total_bc_limit'),
#  (0.0014289419665493488, 'dti'),
#  (0.0008578551798875751, 'num_il_tl'),
#  (0.00040778654511111303, 'percent_bc_gt_75'),
#  (0.000381938675369229, 'total_rec_int'),
#  (0.00014619835480406463, 'inq_fi'),
#  (0.0, 'total_rec_late_fee'),
#  (0.0, 'total_pymnt_inv'),
#  (0.0, 'total_pymnt'),
#  (0.0, 'total_cu_tl'),
#  (0.0, 'recoveries'),
#  (0.0, 'num_tl_120dpd_2m'),
#  (0.0, 'num_bc_tl'),
#  (0.0, 'num_bc_sats')]

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
 
from imblearn.ensemble import EasyEnsembleClassifier
en_model = EasyEnsembleClassifier(n_estimators=300, random_state=1)

en_model.fit(X_train_scaled, y_train)
# Out:
# EasyEnsembleClassifier(n_estimators=300, random_state=1)

# %%
# Display the confusion matrix
 
from sklearn.metrics import confusion_matrix 
y_pred = en_model.predict(X_test_scaled)
confusion_matrix(y_test, y_pred)
# Out:
# array([[   79,     8],
#        [  950, 16168]])

# %%
# Calculated the balanced accuracy score
 
from sklearn.metrics import balanced_accuracy_score 
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9262744197477146

# %%
# Print the imbalanced classification report
 
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.08      0.91      0.94      0.14      0.93      0.85        87
#    low_risk       1.00      0.94      0.91      0.97      0.93      0.86     17118
#
# avg / total       0.99      0.94      0.91      0.97      0.93      0.86     17205

# %% [markdown]
# ### Analysis
#
# 1. Which model had the best balanced accuracy score?
#
#     The easy ensemble model
#
# 2. Which model had the best recall score?
#
#     The easy ensemble model
#
# 3. Which model had the best geometric mean score?
#
#     The easy ensemble model
#
# 4. What are the top three features?
#
#     initial_list_status, out_prncp, total_acc
